# %%
from order_book import OrderBook
from models import Order, ReqType, Request, Trade
from agents import Agent
from simulation import Simulation
from strategies import Random

from collections import deque
from dataclasses import dataclass
from enum import Enum
import matplotlib as plt

# %%
sim = Simulation()

# %%
# create 100 random agents with fixed probabilities
for i in range(1, 101):
    strat = Random(
        buy_probability=0.33,
        sell_probability=0.33,
        cancel_probability=0.2,
        limit_probability=0.8,
        max_quantity=10,
        max_price_offset=10,
    )
    agent = Agent(
        agent_id=i,
        initial_cash=10000,
        initial_position=100,
        strategy=strat
    )
    sim.agents[i] = agent

# %%
sim.run_sim(10000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 sim.run_sim(10000)
#
# File ~/order-book/simulation.py:171, in Simulation.run_sim(self, steps, vb)
#     168     self.spreads.append(None)
#     169     self.mid_prices.append(None) # still need to append something to correctly view the time series
# --> 171 self.sim_history.append(self.get_sim_snapshot(trades_before=trades_before))
#     173 self.timestamp += 1
#
# File ~/order-book/simulation.py:177, in Simulation.get_sim_snapshot(self, trades_before)
#     176 def get_sim_snapshot(self, trades_before: int) -> SimulationSnapshot:
# --> 177     sim_snap = SimulationSnapshot(
#     178         timestamp=self.timestamp,
#     179         best_bid=self.book.biggest_bid(),
#     180         best_ask=self.book.smallest_ask(),
#     181         )
#     182     if sim_snap.best_bid is not None and sim_snap.best_ask is not None:                       # if we can: fetch mid price and spread.
#     183         sim_snap.spread = sim_snap.best_ask - sim_snap.best_bid
#
# TypeError: SimulationSnapshot.__init__() missing 2 required positional arguments: 'mid_price' and 'spread'

# %%
# requests are filling up orders, but a request to cancel the order has already happened first

# %%
len(sim.book.trades)
# Out:
# 379568

# %%
sim.plot("price")

# %%
sim.plot("trade counts")

# %%
sim.plot("spread")
